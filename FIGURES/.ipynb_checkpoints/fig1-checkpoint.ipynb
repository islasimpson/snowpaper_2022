# %%
import importlib
import xarray as xr
import matplotlib.pyplot as plt
import sys
import numpy as np

from CASutils import colormap_utils as mycolmap
from CASutils import mapplot_utils as maps

importlib.reload(mycolmap)
importlib.reload(maps)
# Out:
# <module 'CASutils.mapplot_utils' from '/home/islas/python/CASanalysis/CASutils/mapplot_utils.py'>

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
isdpath="/project/cas/islas/savs/python/snowpaper/DATA_SORT/deseasonalized_tvar/TVAR_ISD.nc"
isd=xr.open_dataset(isdpath)

# %%
goga1path="/project/cas/islas/savs/python/snowpaper/DATA_SORT/deseasonalized_tvar/TVAR_GOGA1.nc"
goga1 = xr.open_dataset(goga1path)
goga1varm = goga1.goga1var.mean('Member')

# %%
goga2path="/project/cas/islas/savs/python/snowpaper/DATA_SORT/deseasonalized_tvar/TVAR_GOGA2.nc"
goga2 = xr.open_dataset(goga2path)
goga2varm = goga2.goga1var.mean('Member')

# %%
fig = plt.figure(figsize=(16,16))
ax1 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga1varm), np.array(goga1varm.lon), np.array(goga1varm.lat), 10, -170, 170, '(a) GOGA1', 0.05, 0.3, 0.8, 0.95)
ax2 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga2varm), np.array(goga2varm.lon), np.array(goga2varm.lat), 10, -170, 170, '(b) GOGA2', 0.35, 0.6, 0.8, 0.95)

# %%
fig=plt.figure(figsize=(16,16))
ax1 = maps.contourmap_bothcontinents_scatter_nh_pos(fig, np.array(isd.isdvar), np.array(isd.lon), np.array(isd.lat), 10, -170, 170, ' ',0.05,0.3,0.8,0.95) 
#ax = fig.add_axes(np.array([0.05,0.05,0.95,0.95]), projection=ccrs.PlateCarree())
#ax.scatter(isd.lon, isd.lat, c=isd.isdvar, marker="o", cmap='RdYlBu_r', vmin=-170, vmax=170)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e62f41fc2f44> in <module>
#       1 fig=plt.figure(figsize=(16,16))
# ----> 2 ax1 = maps.contourmap_bothcontinents_scatter_nh_pos(fig, np.array(isd.isdvar), np.array(isd.lon), np.array(isd.lat), 10, -170, 170, ' ',0.05,0.3,0.8,0.95)
#       3 #ax = fig.add_axes(np.array([0.05,0.05,0.95,0.95]), projection=ccrs.PlateCarree())
#       4 #ax.scatter(isd.lon, isd.lat, c=isd.isdvar, marker="o", cmap='RdYlBu_r', vmin=-170, vmax=170)
#
# ~/python/CASanalysis/CASutils/mapplot_utils.py in contourmap_bothcontinents_scatter_nh_pos(fig, dat, lon, lat, ci, cmin, cmax, titlestr, x1, x2, y1, y2, lonmid, labels, cmap)
#      69     ax.set_title(titlestr, fontsize=16)
#      70
# ---> 71     ax.scatter(lon, lat, c=dat, marker="o", norm=clevs, cmap = mymap)
# ...

# %%
test = np.array(isd.isdvar)

# %%
print(test)
# Out:
# [ 58.68598262 155.7166677   37.94906631 ...  48.25771177  55.04893818
#  104.24282076]

# %%
fig=plt.figure(figsize=(16,16))
ax = fig.add_axes(np.array([0.05,0.05,0.95,0.95]), projection=ccrs.PlateCarree())
ax.scatter(isd.lon, isd.lat, c=isd.isdvar, marker="o", cmap='RdYlBu_r', vmin=-170, vmax=170)
