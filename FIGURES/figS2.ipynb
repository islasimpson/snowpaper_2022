# %%
import importlib
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
import sys
import numpy as np

from CASutils import colormap_utils as mycolors
from CASutils import mapplot_utils as maps
from CASutils import colorbar_utils as cbars


importlib.reload(mycolors)
importlib.reload(maps)
importlib.reload(cbars)
# Out:
# <module 'CASutils.colorbar_utils' from '/home/islas/python/CASanalysis/CASutils/colorbar_utils.py'>

# %%
plotdir="/project/cas/islas/python_plots/snowpaper/FIGURES/"

# %%
goga1path="/project/cas/islas/python_savs/snowpaper/DATA_SORT/deseasonalized_tvar/TREFHTMXVAR_GOGA1.nc"
goga1 = xr.open_dataset(goga1path)
goga1_mx_varm = goga1.goga1var_djf.mean('Member')

goga1path="/project/cas/islas/python_savs/snowpaper/DATA_SORT/deseasonalized_tvar/TREFHTMNVAR_GOGA1.nc"
goga1 = xr.open_dataset(goga1path)
goga1_mn_varm = goga1.goga1var_djf.mean('Member')

# %%
goga2path="/project/cas/islas/python_savs/snowpaper/DATA_SORT/deseasonalized_tvar/TREFHTMXVAR_GOGA2.nc"
goga2 = xr.open_dataset(goga2path)
goga2_mx_varm = goga2.goga2var_djf.mean('Member')

goga2path="/project/cas/islas/python_savs/snowpaper/DATA_SORT/deseasonalized_tvar/TREFHTMNVAR_GOGA2.nc"
goga2 = xr.open_dataset(goga2path)
goga2_mn_varm = goga2.goga2var_djf.mean('Member')

# %%
fig = plt.figure(figsize=(16,16))

ax1 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga1_mx_varm), np.array(goga1_mx_varm.lon), np.array(goga1_mx_varm.lat), 10, -170, 170, '(a) GOGA1, MAX T$_{2m}$', 0.05, 0.32, 0.8, 0.95)

ax2 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga2_mx_varm), np.array(goga2_mx_varm.lon), np.array(goga2_mx_varm.lat), 10, -170, 170, '(b) GOGA2, MAX T$_{2m}$', 0.37, 0.64, 0.8, 0.95)

ax3 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga2_mx_varm)-np.array(goga1_mx_varm), np.array(goga1_mx_varm.lon), np.array(goga1_mx_varm.lat),
                                                5,-80,80,'(c) GOGA2-GOGA1, MAX T$_{2m}$', 0.69,0.97,0.8,0.95)

ax4 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga1_mn_varm), np.array(goga1_mn_varm.lon), np.array(goga1_mn_varm.lat), 10, -170, 170, 
                                                 '(d) GOGA1, MIN T$_{2m}$', 0.05, 0.32, 0.6, 0.75)

ax5 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga2_mn_varm), np.array(goga2_mn_varm.lon), np.array(goga2_mn_varm.lat), 10, -170, 170, 
                                                 '(e) GOGA2, MIN T$_{2m}$', 0.37, 0.64, 0.6, 0.75)

ax6 = maps.contourmap_bothcontinents_fill_nh_pos(fig, np.array(goga2_mn_varm)-np.array(goga1_mn_varm), np.array(goga1_mn_varm.lon), np.array(goga1_mn_varm.lat),
                                                5,-80,80,'(f) GOGA2-GOGA1, MIN T$_{2m}$', 0.69,0.97,0.6,0.75)

ax7 = cbars.plotcolorbar(fig,10, -170, 170,'Temperature variance (K$^{2}$)',0.05+0.05,0.64-0.05,0.56, 0.57, posneg='pos',ticks=([0,20,40,60,80,100,120,140,160]), fsize=12)
ax9 = cbars.plotcolorbar(fig, 5, -80, 80,'Temperature variance (K$^{2}$)',0.69,0.97,0.56,0.57, ticks=([-60,-40,-20,0,20,40,60]), fsize=12)

# %%
fig.savefig(plotdir+"figS2.pdf", facecolor="white", bbox_inches="tight")
